# %%
# !pip install opendatasets
# Out:
# Requirement already satisfied: opendatasets in c:\users\asus ryzen\anaconda3\lib\site-packages (0.1.20)
# Requirement already satisfied: tqdm in c:\users\asus ryzen\anaconda3\lib\site-packages (from opendatasets) (4.50.2)
# Requirement already satisfied: kaggle in c:\users\asus ryzen\anaconda3\lib\site-packages (from opendatasets) (1.5.12)
# Requirement already satisfied: click in c:\users\asus ryzen\anaconda3\lib\site-packages (from opendatasets) (7.1.2)
# Requirement already satisfied: python-dateutil in c:\users\asus ryzen\anaconda3\lib\site-packages (from kaggle->opendatasets) (2.8.1)
# Requirement already satisfied: certifi in c:\users\asus ryzen\anaconda3\lib\site-packages (from kaggle->opendatasets) (2020.6.20)
# Requirement already satisfied: urllib3 in c:\users\asus ryzen\anaconda3\lib\site-packages (from kaggle->opendatasets) (1.25.11)
# Requirement already satisfied: six>=1.10 in c:\users\asus ryzen\anaconda3\lib\site-packages (from kaggle->opendatasets) (1.15.0)
# Requirement already satisfied: requests in c:\users\asus ryzen\anaconda3\lib\site-packages (from kaggle->opendatasets) (2.24.0)
# Requirement already satisfied: python-slugify in c:\users\asus ryzen\anaconda3\lib\site-packages (from kaggle->opendatasets) (5.0.2)
# Requirement already satisfied: chardet<4,>=3.0.2 in c:\users\asus ryzen\anaconda3\lib\site-packages (from requests->kaggle->opendatasets) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\asus ryzen\anaconda3\lib\site-packages (from requests->kaggle->opendatasets) (2.10)
# Requirement already satisfied: text-unidecode>=1.3 in c:\users\asus ryzen\anaconda3\lib\site-packages (from python-slugify->kaggle->opendatasets) (1.3)

# %% [markdown]
# # Load

# %% [markdown]
# Link Data Set : https://www.kaggle.com/jtiptj/chest-xray-pneumoniacovid19tuberculosis

# %%
import opendatasets as od
import os

# %%
{"username":"huseinabdulh","key":"e953505bd13b6491beac8d1916f15533"}
# Out:
# {'username': 'huseinabdulh', 'key': 'e953505bd13b6491beac8d1916f15533'}

# %%
'''od.download('https://www.kaggle.com/jtiptj/chest-xray-pneumoniacovid19tuberculosis')'''
# Out:
# "od.download('https://www.kaggle.com/jtiptj/chest-xray-pneumoniacovid19tuberculosis')"

# %%
cd C:\Users\ASUS RYZEN\AnacondaJupyter\ML_Praktikum\Modul4
# Out:
# C:\Users\ASUS RYZEN\AnacondaJupyter\ML_Praktikum\Modul4

# %%
ls
# Out:
#  Volume in drive C is OS
#  Volume Serial Number is 70B6-E30C
#
#  Directory of C:\Users\ASUS RYZEN\AnacondaJupyter\ML_Praktikum\Modul4
#
# 11/29/2021  08:36 AM           266,850 (versi 2) Modul 4 ML - Handling Overfit Problem #2 .ipynb
# 11/29/2021  08:36 AM             8,430 (versi 3) Kegiatan Modul 4.ipynb
# 11/30/2021  06:11 PM    <DIR>          .
# 11/30/2021  06:11 PM    <DIR>          ..
# 11/30/2021  06:11 PM    <DIR>          .ipynb_checkpoints
# 11/30/2021  06:10 PM         1,314,531 All_Combined_Fixed.ipynb
# 11/29/2021  08:44 AM    <DIR>          chest-xray-pneumoniacovid19tuberculosis
# 11/29/2021  06:16 PM         1,311,887 Coba1.ipynb
# 11/29/2021  09:10 AM    <DIR>          DataSet
# 11/29/2021  09:13 AM    <DIR>          DataSet_Splitted
# 11/30/2021  03:36 AM         1,301,859 Fixed.ipynb
# 11/30/2021  02:19 PM         1,314,531 Fixed2.ipynb
# 11/30/2021  03:35 AM    <DIR>          SavedModel
#                6 File(s)      5,518,088 bytes
#                7 Dir(s)  352,332,500,992 bytes free

# %%
'C:/Users/ASUS RYZEN/AnacondaJupyter/ML_Praktikum/Modul4/DataSet'
# Out:
# 'C:/Users/ASUS RYZEN/AnacondaJupyter/ML_Praktikum/Modul4/DataSet'

# %%
dataset_awal = 'C:/Users/ASUS RYZEN/AnacondaJupyter/ML_Praktikum/Modul4/DataSet'

print('Number of classes: {}'.format(len(os.listdir(dataset_awal))))
#print('Number of datas: {}'.format(tot_data_noclean))
print('')

covid19 = len(os.listdir(dataset_awal+'/COVID19'))
normal = len(os.listdir(dataset_awal+'/NORMAL'))
pneumonia = len(os.listdir(dataset_awal+'/PNEUMONIA'))
tuberculosis = len(os.listdir(dataset_awal+'/TURBERCULOSIS'))

print("DATASET AWAL ")
print('covid19 : ', covid19)
print('normal : ', normal)
print('pneumonia : ', pneumonia)
print('tuberculosis : ', tuberculosis)
# Out:
# Number of classes: 4
#
# DATASET AWAL
# covid19 :  566
# normal :  1575
# pneumonia :  4265
# tuberculosis :  691

# %%
'''import splitfolders'''
'''
base_dir="C:/Users/ASUS RYZEN/AnacondaJupyter/ML_Praktikum/Modul4/DataSet"
data_dir="C:/Users/ASUS RYZEN/AnacondaJupyter/ML_Praktikum/Modul4/DataSet_Splitted"
splitfolders.ratio(base_dir, output=data_dir, seed=1337, ratio=(.8 ,0.19 ,0.01),group_prefix=None)'''
# Out:
# '\nbase_dir="C:/Users/ASUS RYZEN/AnacondaJupyter/ML_Praktikum/Modul4/DataSet"\ndata_dir="C:/Users/ASUS RYZEN/AnacondaJupyter/ML_Praktikum/Modul4/DataSet_Splitted"\nsplitfolders.ratio(base_dir, output=data_dir, seed=1337, ratio=(.8 ,0.19 ,0.01),group_prefix=None)'

# %%
#Define a path
base_dir = 'C:/Users/ASUS RYZEN/AnacondaJupyter/ML_Praktikum/Modul4/DataSet_Splitted'
train_dir = os.path.join(base_dir, 'train')
validation_dir = os.path.join(base_dir, 'val')
test_dir = os.path.join(base_dir, 'test')

train_covid19_dir = os.path.join(train_dir, 'covid19')
train_normal_dir = os.path.join(train_dir, 'normal')
train_pneumonia_dir = os.path.join(train_dir, 'pneumonia')
train_turberculosis_dir = os.path.join(train_dir, 'turberculosis')

validation_covid19_dir = os.path.join(validation_dir, 'covid19')
validation_normal_dir = os.path.join(validation_dir, 'normal')
validation_pneumonia_dir = os.path.join(validation_dir, 'pneumonia')
validation_turberculosis_dir = os.path.join(validation_dir, 'turberculosis')

test_covid19_dir = os.path.join(test_dir, 'covid19')
test_normal_dir = os.path.join(test_dir, 'normal')
test_pneumonia_dir = os.path.join(test_dir, 'pneumonia')
test_turberculosis_dir = os.path.join(test_dir, 'turberculosis')

# %%
print('Train : ')
print('Train Covid19 :', len(os.listdir(train_covid19_dir)))
print('Train Normal :', len(os.listdir(train_normal_dir)))
print('Train Pneumonia :', len(os.listdir(train_pneumonia_dir)))
print('Train Tuberculosis :', len(os.listdir(train_turberculosis_dir)))
print(""*2)
print('Validation : ')
print('Validation Covid19 :', len(os.listdir(validation_covid19_dir)))
print('Validation Normal :', len(os.listdir(validation_normal_dir)))
print('Validation Pneumonia :', len(os.listdir(validation_pneumonia_dir)))
print('Validation Tuberculosis :', len(os.listdir(validation_turberculosis_dir)))
print(""*2)
print('Test : ')
print('Test Covid19 :', len(os.listdir(test_covid19_dir)))
print('Test Normal :', len(os.listdir(test_normal_dir)))
print('Test Pneumonia :', len(os.listdir(test_pneumonia_dir)))
print('Test Tuberculosis :', len(os.listdir(test_turberculosis_dir)))
# Out:
# Train :
# Train Covid19 : 452
# Train Normal : 1260
# Train Pneumonia : 3412
# Train Tuberculosis : 552
#
# Validation :
# Validation Covid19 : 107
# Validation Normal : 299
# Validation Pneumonia : 810
# Validation Tuberculosis : 131
#
# Test :
# Test Covid19 : 7
# Test Normal : 16
# Test Pneumonia : 43
# Test Tuberculosis : 8

# %%
# Tampilkan 8 image per kelas dengan ukuran 4x4 

# %matplotlib inline

import matplotlib.pyplot as plt
import matplotlib.image as mpimg

nrows = 4
ncols = 4

pic_index = 0

fig = plt.gcf()
fig.set_size_inches( ncols * 4,nrows * 4)

pic_index += 8
Train_covid19 = [os.path.join(train_covid19_dir, fname) 
                for fname in os.listdir(train_covid19_dir)[pic_index-4:pic_index]]

Train_normal = [os.path.join(train_normal_dir, fname) 
                for fname in os.listdir(train_normal_dir)[pic_index-4:pic_index]]

Train_pneumonia = [os.path.join(train_pneumonia_dir, fname) 
                for fname in os.listdir(train_pneumonia_dir)[pic_index-4:pic_index]]

Train_turberculosis= [os.path.join(train_turberculosis_dir, fname) 
                for fname in os.listdir(train_turberculosis_dir)[pic_index-4:pic_index]]
for i, img_path in enumerate(Train_covid19+Train_normal+Train_pneumonia+Train_turberculosis):
    
  # Set up subplot; subplot indices start at 1
  sp = plt.subplot(nrows, ncols, i + 1)
  sp.axis('Off') # Don't show axes (or gridlines)

  img = mpimg.imread(img_path)
  plt.imshow(img)
  plt.title(img_path.split(os.path.sep)[-2])

plt.show()

# %% [markdown]
# # Preprocessing

# %%
'C:/Users/ASUS RYZEN/AnacondaJupyter/ML_Praktikum/Modul4/DataSet_Spiltted'
# Out:
# 'C:/Users/ASUS RYZEN/AnacondaJupyter/ML_Praktikum/Modul4/DataSet_Spiltted'

# %%
ls
# Out:
#  Volume in drive C is OS
#  Volume Serial Number is 70B6-E30C
#
#  Directory of C:\Users\ASUS RYZEN\AnacondaJupyter\ML_Praktikum\Modul4
#
# 11/29/2021  08:36 AM           266,850 (versi 2) Modul 4 ML - Handling Overfit Problem #2 .ipynb
# 11/29/2021  08:36 AM             8,430 (versi 3) Kegiatan Modul 4.ipynb
# 11/30/2021  06:11 PM    <DIR>          .
# 11/30/2021  06:11 PM    <DIR>          ..
# 11/30/2021  06:11 PM    <DIR>          .ipynb_checkpoints
# 11/30/2021  06:10 PM         1,314,531 All_Combined_Fixed.ipynb
# 11/29/2021  08:44 AM    <DIR>          chest-xray-pneumoniacovid19tuberculosis
# 11/29/2021  06:16 PM         1,311,887 Coba1.ipynb
# 11/29/2021  09:10 AM    <DIR>          DataSet
# 11/29/2021  09:13 AM    <DIR>          DataSet_Splitted
# 11/30/2021  03:36 AM         1,301,859 Fixed.ipynb
# 11/30/2021  02:19 PM         1,314,531 Fixed2.ipynb
# 11/30/2021  03:35 AM    <DIR>          SavedModel
#                6 File(s)      5,518,088 bytes
#                7 Dir(s)  352,332,484,608 bytes free

# %%
# !pip3 install keras
# Out:
# Requirement already satisfied: keras in c:\users\asus ryzen\anaconda3\lib\site-packages (2.6.0)

# %%
import tensorflow as tf
from tensorflow.keras.optimizers import RMSprop
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
TRAINING_DIR = "C:/Users/ASUS RYZEN/AnacondaJupyter/ML_Praktikum/Modul4/DataSet_Splitted/train"
VALIDATION_DIR = "C:/Users/ASUS RYZEN/AnacondaJupyter/ML_Praktikum/Modul4/DataSet_Splitted/val"
TEST_DIR = "C:/Users/ASUS RYZEN/AnacondaJupyter/ML_Praktikum/Modul4/DataSet_Splitted/test"

datagen = ImageDataGenerator(rescale=0)

train_gen = datagen.flow_from_directory(
    TRAINING_DIR,
    target_size=(150,150),
    shuffle=True,
    class_mode='categorical'
)

val_gen = datagen.flow_from_directory(
    VALIDATION_DIR,
    target_size=(150,150),
    shuffle=False,
    class_mode='categorical'
)

test_gen = datagen.flow_from_directory(
    TEST_DIR,
    target_size=(150,150),
    shuffle=False,
    class_mode='categorical'
)
# Out:
# Found 5676 images belonging to 4 classes.
# Found 1347 images belonging to 4 classes.
# Found 74 images belonging to 4 classes.

# %%
import tensorflow as tf
from tensorboard.plugins.hparams import api as hp

# %%
# %load_ext tensorboard
# Out:
# The tensorboard extension is already loaded. To reload it, use:
#   %reload_ext tensorboard

# %%
# !rm -rf ./logs/
# Out:
# 'rm' is not recognized as an internal or external command,
# operable program or batch file.

# %%
HP_NUM_UNITS = hp.HParam('num_units', hp.Discrete([64, 128]))
HP_DROPOUT = hp.HParam('dropout', hp.RealInterval(0.4, 0.5))
HP_OPTIMIZER = hp.HParam('optimizer', hp.Discrete(['adam', 'adadelta']))

METRIC_ACCURACY = 'accuracy'
hparam_summary_dir = 'C:/Users/ASUS RYZEN/AnacondaJupyter/ML_Praktikum/Modul4/hparam_summary_dir'

first_mine_model_dict = dict()
first_mine_history_dict = dict()

second_mine_model_dict = dict()
second_mine_history_dict = dict()

# %%
#Definisikan x_val dan y_val dari validation data untuk evaluasi model.
import numpy as np
xtest, ytest = zip(*(test_gen[i] for i in range(len(test_gen))))
x_test, y_test = np.vstack(xtest), np.vstack(ytest)

# %% [markdown]
# # Define Modelling

# %%
# IMPORT SEMUA PAKET YANG ANDA PERLUKAN UNTUK MENDEFINISIKAN MODEL DISINI
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import InputLayer, Dense, Conv2D,MaxPool2D, AveragePooling2D, GlobalAveragePooling2D, Flatten, BatchNormalization, Dropout
from tensorflow.keras.callbacks import ModelCheckpoint, ReduceLROnPlateau, EarlyStopping
from tensorflow.keras.optimizers import Adam
import time

# %%
def train_test_first_model(hparams, session_num):
    global first_mine_model_dict
    global first_mine_history_dict

    model = Sequential()

    # Feature Extraction Layer
    model.add(InputLayer(input_shape=(150,150,3,)))
    model.add(Conv2D(16, 3, padding='same', activation='relu'))
    model.add(MaxPool2D())
    model.add(Conv2D(16, 3, padding='same', activation='relu'))
    model.add(MaxPool2D())
   
    model.add(BatchNormalization())
    model.add(Flatten())

    # Fully Connected Layer
    model.add(Dense(hparams[HP_NUM_UNITS], activation='relu'))
    model.add(Dense(36, activation='relu'))
    model.add(Dropout(hparams[HP_DROPOUT]))
    model.add(Dense(4, activation='softmax'))

    # Compile Model
    model.compile(
        optimizer=hparams[HP_OPTIMIZER],
        loss='categorical_crossentropy',
        metrics='accuracy'
    )

    # Fit Model
    H = model.fit(train_gen,
                  validation_data=val_gen, 
                  epochs=50,
                  )
    
    # Gather Model and History
    first_mine_model_dict[session_num] = model
    first_mine_history_dict[session_num] = H.history

    # Evaluate Model
    _, accuracy = model.evaluate(x_test, y_test)

    return accuracy

# %%
#Definisikan fungsi run
def first_model_run(run_dir, hparams, session_num):
    with tf.summary.create_file_writer(run_dir).as_default():
        hp.hparams(hparams)
        accuracy = train_test_first_model(hparams, session_num)
        tf.summary.scalar(METRIC_ACCURACY, accuracy, step=50)

# %%
#Grid Search Training Model
#['adam', 'sgd', 'adadelta', 'rmsprop', 'adamx', 'nadam']

# %%
session_num = 0

for num_units in HP_NUM_UNITS.domain.values:
    for dropout_rate in (HP_DROPOUT.domain.min_value, HP_DROPOUT.domain.max_value):
        for optimizer in HP_OPTIMIZER.domain.values:
            hparams = {
                HP_NUM_UNITS: num_units,
                HP_DROPOUT: dropout_rate,
                HP_OPTIMIZER: optimizer,
            }
            run_name = "first_model_run-%d" % session_num
            print('--- Starting trial: %s' % run_name)
            print({h.name: hparams[h] for h in hparams})
            first_model_run((hparam_summary_dir + '/' + run_name), hparams, session_num)
            session_num += 1
# Out:
# --- Starting trial: first_model_run-0
# {'num_units': 64, 'dropout': 0.4, 'optimizer': 'adadelta'}
# Epoch 1/50
# 178/178 [==============================] - 265s 1s/step - loss: 1.8737 - accuracy: 0.3261 - val_loss: 1.0133 - val_accuracy: 0.6244
# Epoch 2/50
# 178/178 [==============================] - 261s 1s/step - loss: 1.1708 - accuracy: 0.5522 - val_loss: 0.7790 - val_accuracy: 0.7045
# Epoch 3/50
# 178/178 [==============================] - 242s 1s/step - loss: 0.9886 - accuracy: 0.6121 - val_loss: 0.6705 - val_accuracy: 0.7424
# Epoch 4/50
# 178/178 [==============================] - 234s 1s/step - loss: 0.8500 - accuracy: 0.6781 - val_loss: 0.5928 - val_accuracy: 0.7751
# Epoch 5/50
# 178/178 [==============================] - 204s 1s/step - loss: 0.8022 - accuracy: 0.6873 - val_loss: 0.5366 - val_accuracy: 0.8025
# Epoch 6/50
# 178/178 [==============================] - 207s 1s/step - loss: 0.7092 - accuracy: 0.7390 - val_loss: 0.4910 - val_accuracy: 0.8218
# Epoch 7/50
# 178/178 [==============================] - 207s 1s/step - loss: 0.6816 - accuracy: 0.7490 - val_loss: 0.4528 - val_accuracy: 0.8441
# Epoch 8/50
# 178/178 [==============================] - 223s 1s/step - loss: 0.6196 - accuracy: 0.7794 - val_loss: 0.4209 - val_accuracy: 0.8582
# Epoch 9/50
# 178/178 [==============================] - 220s 1s/step - loss: 0.5886 - accuracy: 0.7862 - val_loss: 0.3948 - val_accuracy: 0.8693
# Epoch 10/50
# 178/178 [==============================] - 217s 1s/step - loss: 0.5640 - accuracy: 0.7960 - val_loss: 0.3739 - val_accuracy: 0.8745
# Epoch 11/50
# 178/178 [==============================] - 216s 1s/step - loss: 0.5160 - accuracy: 0.8063 - val_loss: 0.3525 - val_accuracy: 0.8849
# Epoch 12/50
# 178/178 [==============================] - 215s 1s/step - loss: 0.5098 - accuracy: 0.8183 - val_loss: 0.3384 - val_accuracy: 0.8894
# Epoch 13/50
# 178/178 [==============================] - 219s 1s/step - loss: 0.4933 - accuracy: 0.8244 - val_loss: 0.3229 - val_accuracy: 0.8983
# Epoch 14/50
# 178/178 [==============================] - 215s 1s/step - loss: 0.4836 - accuracy: 0.8315 - val_loss: 0.3105 - val_accuracy: 0.9027
# Epoch 15/50
# 178/178 [==============================] - 217s 1s/step - loss: 0.4748 - accuracy: 0.8274 - val_loss: 0.3011 - val_accuracy: 0.9109
# Epoch 16/50
# 178/178 [==============================] - 219s 1s/step - loss: 0.4383 - accuracy: 0.8407 - val_loss: 0.2901 - val_accuracy: 0.9109
# Epoch 17/50
# 178/178 [==============================] - 213s 1s/step - loss: 0.4261 - accuracy: 0.8481 - val_loss: 0.2819 - val_accuracy: 0.9117
# Epoch 18/50
# 178/178 [==============================] - 220s 1s/step - loss: 0.4271 - accuracy: 0.8466 - val_loss: 0.2771 - val_accuracy: 0.9161
# Epoch 19/50
# 178/178 [==============================] - 222s 1s/step - loss: 0.4048 - accuracy: 0.8609 - val_loss: 0.2699 - val_accuracy: 0.9154
# Epoch 20/50
# 178/178 [==============================] - 231s 1s/step - loss: 0.4058 - accuracy: 0.8608 - val_loss: 0.2631 - val_accuracy: 0.9161
# Epoch 21/50
# 178/178 [==============================] - 221s 1s/step - loss: 0.3800 - accuracy: 0.8647 - val_loss: 0.2591 - val_accuracy: 0.9213
# Epoch 22/50
# 178/178 [==============================] - 219s 1s/step - loss: 0.3829 - accuracy: 0.8636 - val_loss: 0.2529 - val_accuracy: 0.9235
# Epoch 23/50
# 178/178 [==============================] - 218s 1s/step - loss: 0.3790 - accuracy: 0.8661 - val_loss: 0.2488 - val_accuracy: 0.9250
# Epoch 24/50
# 178/178 [==============================] - 229s 1s/step - loss: 0.3882 - accuracy: 0.8666 - val_loss: 0.2450 - val_accuracy: 0.9228
# Epoch 25/50
# 178/178 [==============================] - 221s 1s/step - loss: 0.3564 - accuracy: 0.8791 - val_loss: 0.2406 - val_accuracy: 0.9243
# Epoch 26/50
# 178/178 [==============================] - 223s 1s/step - loss: 0.3520 - accuracy: 0.8822 - val_loss: 0.2382 - val_accuracy: 0.9287
# Epoch 27/50
# 178/178 [==============================] - 218s 1s/step - loss: 0.3477 - accuracy: 0.8775 - val_loss: 0.2343 - val_accuracy: 0.9287
# Epoch 28/50
# 178/178 [==============================] - 221s 1s/step - loss: 0.3365 - accuracy: 0.8874 - val_loss: 0.2317 - val_accuracy: 0.9295
# Epoch 29/50
# 178/178 [==============================] - 222s 1s/step - loss: 0.3234 - accuracy: 0.8943 - val_loss: 0.2277 - val_accuracy: 0.9310
# Epoch 30/50
# 178/178 [==============================] - 224s 1s/step - loss: 0.3496 - accuracy: 0.8845 - val_loss: 0.2267 - val_accuracy: 0.9310
# Epoch 31/50
# 178/178 [==============================] - 229s 1s/step - loss: 0.3264 - accuracy: 0.8848 - val_loss: 0.2241 - val_accuracy: 0.9317
# Epoch 32/50
# 178/178 [==============================] - 232s 1s/step - loss: 0.3383 - accuracy: 0.8866 - val_loss: 0.2207 - val_accuracy: 0.9332
# Epoch 33/50
# 178/178 [==============================] - 225s 1s/step - loss: 0.3262 - accuracy: 0.8908 - val_loss: 0.2190 - val_accuracy: 0.9324
# Epoch 34/50
# 178/178 [==============================] - 229s 1s/step - loss: 0.3278 - accuracy: 0.8874 - val_loss: 0.2167 - val_accuracy: 0.9347
# Epoch 35/50
# 178/178 [==============================] - 234s 1s/step - loss: 0.3031 - accuracy: 0.9032 - val_loss: 0.2146 - val_accuracy: 0.9362
# Epoch 36/50
# 178/178 [==============================] - 240s 1s/step - loss: 0.3034 - accuracy: 0.8980 - val_loss: 0.2128 - val_accuracy: 0.9339
# Epoch 37/50
# 178/178 [==============================] - 227s 1s/step - loss: 0.3109 - accuracy: 0.8938 - val_loss: 0.2117 - val_accuracy: 0.9354
# Epoch 38/50
# 178/178 [==============================] - 225s 1s/step - loss: 0.2852 - accuracy: 0.9019 - val_loss: 0.2101 - val_accuracy: 0.9362
# Epoch 39/50
# 178/178 [==============================] - 227s 1s/step - loss: 0.2820 - accuracy: 0.9067 - val_loss: 0.2082 - val_accuracy: 0.9362
# Epoch 40/50
# 178/178 [==============================] - 235s 1s/step - loss: 0.2986 - accuracy: 0.9061 - val_loss: 0.2055 - val_accuracy: 0.9362
# Epoch 41/50
# 178/178 [==============================] - 228s 1s/step - loss: 0.2987 - accuracy: 0.9005 - val_loss: 0.2066 - val_accuracy: 0.9376
# Epoch 42/50
# 178/178 [==============================] - 224s 1s/step - loss: 0.2865 - accuracy: 0.9079 - val_loss: 0.2036 - val_accuracy: 0.9369
# Epoch 43/50
# 178/178 [==============================] - 231s 1s/step - loss: 0.2807 - accuracy: 0.9013 - val_loss: 0.2015 - val_accuracy: 0.9347
# Epoch 44/50
# 178/178 [==============================] - 233s 1s/step - loss: 0.2801 - accuracy: 0.9091 - val_loss: 0.2016 - val_accuracy: 0.9369
# Epoch 45/50
# 178/178 [==============================] - 236s 1s/step - loss: 0.2849 - accuracy: 0.9051 - val_loss: 0.2005 - val_accuracy: 0.9354
# Epoch 46/50
# 178/178 [==============================] - 229s 1s/step - loss: 0.2787 - accuracy: 0.9094 - val_loss: 0.2003 - val_accuracy: 0.9376
# Epoch 47/50
# 178/178 [==============================] - 238s 1s/step - loss: 0.2702 - accuracy: 0.9102 - val_loss: 0.1979 - val_accuracy: 0.9376
# Epoch 48/50
# 178/178 [==============================] - 240s 1s/step - loss: 0.2602 - accuracy: 0.9095 - val_loss: 0.1965 - val_accuracy: 0.9376
# Epoch 49/50
# 178/178 [==============================] - 266s 1s/step - loss: 0.2795 - accuracy: 0.9049 - val_loss: 0.1964 - val_accuracy: 0.9391
# Epoch 50/50
# 178/178 [==============================] - 243s 1s/step - loss: 0.2698 - accuracy: 0.9103 - val_loss: 0.1947 - val_accuracy: 0.9384
# 3/3 [==============================] - 1s 49ms/step - loss: 0.2045 - accuracy: 0.9189
# --- Starting trial: first_model_run-1
# {'num_units': 64, 'dropout': 0.4, 'optimizer': 'adam'}
# Epoch 1/50
# 178/178 [==============================] - 314s 2s/step - loss: 0.9534 - accuracy: 0.7341 - val_loss: 1.2424 - val_accuracy: 0.7751
# Epoch 2/50
# 178/178 [==============================] - 407s 2s/step - loss: 0.3636 - accuracy: 0.8846 - val_loss: 10.4305 - val_accuracy: 0.2918
# Epoch 3/50
# 178/178 [==============================] - 394s 2s/step - loss: 0.2507 - accuracy: 0.9229 - val_loss: 0.2420 - val_accuracy: 0.9339
# Epoch 4/50
# 178/178 [==============================] - 335s 2s/step - loss: 0.1679 - accuracy: 0.9425 - val_loss: 0.2194 - val_accuracy: 0.9369
# Epoch 5/50
# 178/178 [==============================] - 246s 1s/step - loss: 0.1321 - accuracy: 0.9508 - val_loss: 0.4011 - val_accuracy: 0.9079
# Epoch 6/50
# 178/178 [==============================] - 243s 1s/step - loss: 0.1016 - accuracy: 0.9583 - val_loss: 0.6267 - val_accuracy: 0.8515
# Epoch 7/50
# 178/178 [==============================] - 252s 1s/step - loss: 0.1034 - accuracy: 0.9597 - val_loss: 0.4928 - val_accuracy: 0.9057
# Epoch 8/50
# 178/178 [==============================] - 246s 1s/step - loss: 0.0842 - accuracy: 0.9689 - val_loss: 0.3319 - val_accuracy: 0.9280
# Epoch 9/50
# 178/178 [==============================] - 248s 1s/step - loss: 0.0603 - accuracy: 0.9793 - val_loss: 0.3418 - val_accuracy: 0.9414
# Epoch 10/50
# 178/178 [==============================] - 249s 1s/step - loss: 0.0735 - accuracy: 0.9745 - val_loss: 0.3088 - val_accuracy: 0.9384
# Epoch 11/50
# 178/178 [==============================] - 250s 1s/step - loss: 0.0320 - accuracy: 0.9895 - val_loss: 0.2853 - val_accuracy: 0.9421
# Epoch 12/50
# 178/178 [==============================] - 248s 1s/step - loss: 0.0454 - accuracy: 0.9861 - val_loss: 0.5431 - val_accuracy: 0.9191
# Epoch 13/50
# 170/178 [===========================>..] - ETA: 10s - loss: 0.0604 - accuracy: 0.9806

# %% [markdown]
# # Model Evaluation

# %%
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn import metrics
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.preprocessing.image import ImageDataGenerator, load_img, img_to_array
import cv2

# %%
import json
from tensorflow.keras.models import load_model
model.save('C:/Users/ASUS RYZEN/AnacondaJupyter/ML_Praktikum/Modul4/SavedModel/best_model_train_Fixed2.h5')

# %% [markdown]
# ## Plotting dan Accuracy

# %%
print(H.history.keys())
# Out:
# dict_keys(['loss', 'acc', 'val_loss', 'val_acc'])

# %%
acc = H.history['acc']
val_acc = H.history['val_acc']
loss = H.history['loss']
val_loss = H.history['val_loss']

epochs = range(len(acc))

plt.plot(epochs, acc, 'bo', label='Training accuracy')
plt.plot(epochs, val_acc, 'b', label='Validation accuracy')
plt.title('Training and validation accuracy')

plt.figure()

plt.plot(epochs, loss, 'bo', label='Training Loss')
plt.plot(epochs, val_loss, 'b', label='Validation Loss')
plt.title('Training and validation loss')
plt.legend()

plt.show()

# %% [markdown]
# ## Classification Report dan Confusion

# %%
datagen = ImageDataGenerator(rescale=1.0/255.0)

test_generator = datagen.flow_from_directory(
        test_dir,
        target_size=(150, 150),
        shuffle=False,
        class_mode='categorical')
# Out:
# Found 74 images belonging to 4 classes.

# %%
import json
from tensorflow.keras.models import load_model
target_dir = 'C:/Users/ASUS RYZEN/AnacondaJupyter/ML_Praktikum/Modul4/SavedModel/'
model_saved = load_model(target_dir + 'best_model_train_Fixed2.h5')

# %%
test_score = model_saved.evaluate_generator(test_generator, test_generator.batch_size)
print("[INFO] accuracy: {:.2f}%".format(test_score[1] * 100)) 
print("[INFO] Loss: ",test_score[0])
# Out:
# C:\Users\ASUS RYZEN\anaconda3\lib\site-packages\tensorflow\python\keras\engine\training.py:1877: UserWarning: `Model.evaluate_generator` is deprecated and will be removed in a future version. Please use `Model.evaluate`, which supports generators.
#   warnings.warn('`Model.evaluate_generator` is deprecated and '
# WARNING:tensorflow:Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches (in this case, 32 batches). You may need to use the repeat() function when building your dataset.
# [INFO] accuracy: 67.57%
# [INFO] Loss:  1.401379108428955

# %%
#Print the Target names
target_names = []
for key in train_generator.class_indices:
    target_names.append(key)
print(target_names)
# Out:
# ['COVID19', 'NORMAL', 'PNEUMONIA', 'TURBERCULOSIS']

# %%
from sklearn.metrics import classification_report

Y_pred = model.predict_generator(test_generator)
y_pred = np.argmax(Y_pred, axis=1)

print('Classification Report')
print(classification_report(test_generator.classes, y_pred, target_names=target_names))
# Out:
# C:\Users\ASUS RYZEN\anaconda3\lib\site-packages\tensorflow\python\keras\engine\training.py:1905: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   warnings.warn('`Model.predict_generator` is deprecated and '
# Classification Report
#                precision    recall  f1-score   support
#
#       COVID19       1.00      0.29      0.44         7
#        NORMAL       0.00      0.00      0.00        16
#     PNEUMONIA       0.64      1.00      0.78        43
# TURBERCULOSIS       1.00      0.62      0.77         8
#
#      accuracy                           0.68        74
#     macro avg       0.66      0.48      0.50        74
#  weighted avg       0.58      0.68      0.58        74
# C:\Users\ASUS RYZEN\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1221: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
Cmatrix_test = confusion_matrix(test_generator.classes, y_pred)
class_names = test_generator.class_indices

plt.figure(figsize = (15,12))
ax = plt.subplot()
sns.set(font_scale=2.0) # Adjust to fit
sns.heatmap(Cmatrix_test,annot=True, fmt='',ax=ax, cmap=plt.cm.Reds)

# labels, title and ticks
label_font = {'size':'15'}  # Adjust to fit
ax.set_xlabel('Predicted labels', fontdict=label_font)
ax.set_ylabel('True labels', fontdict=label_font) 

title_font = {'size':'18'}  # Adjust to fit
ax.set_title('Confusion Matrix', fontdict=title_font)

ax.tick_params(axis='both', which='major', labelsize=15)  # Adjust to fit
ax.xaxis.set_ticklabels(class_names)   
ax.yaxis.set_ticklabels(class_names)
plt.title('Confusion Matrix Test',fontsize=14)
plt.show()
